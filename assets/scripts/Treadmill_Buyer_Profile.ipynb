# %% [markdown]
# # EDA Portfolio Project - Treadmill Buyer Profile

# %% [markdown]
# ## Project Details:
# The market research team at AeroFit wants to identify the characteristics of the target
# audience for each type of treadmill oƯered by the company, to provide a better
# recommendation of the treadmills to new customers. The team decides to investigate
# whether there are diƯerences across the product with respect to customer
# characteristics.
# ## Product Portfolio:
# 1. The KP281 is an entry-level treadmill that sells for $1,500;
#
# 2. The KP481 is for mid-level runners and sells for $1,750;
#
# 3. The KP781 treadmill have advanced features, and it sells for $2,500.
#
# ## Data Description:
# The company collected data on individuals who purchased a treadmill from the AeroFit
# stores during the prior three months. The dataset in aerofit_treadmill_data.csv has the
# following features:
# 1. Product - product purchased: KP281, KP481, or KP781
# 2. Age - in years
# 3. Gender - male/female
# 4. Education - in years
# 5. MaritalStatus - single or partnered
# 6. Usage - the average number of times the customer plans to use the treadmill
# each week
# 7. Fitness - self-rated fitness on a 1-5 scale, where 1 is the poor shape and 5 is the
# excellent shape
# 8. Income - annual income in US dollars
# 9. Miles - the average number of miles the customer expects to walk/run each week
#
# ## Practicalities:
# Analyse the provided data and provide insights to the best of your abilities. Include the
# relevant tables/graphs/visualization to explain what you have learned about the data.
# You may structure your EDA/Business Analysis according to these steps:

# %% [markdown]
# 1. Data Exploration and Processing:
# - Importing data
# - Reading dataframe
# - Check the shape of the dataframe
# - Datatype of each column
# - Missing value detection
# - Checking duplicate values in the dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from warnings import filterwarnings
filterwarnings("ignore")

# %%
df = pd.read_csv("/content/aerofit_treadmill_data.csv")

# %%
df.head(5)
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18    Male         14        Single      3        4   29562    112
# 1   KP281   19    Male         15        Single      2        3   31836     75
# 2   KP281   19  Female         14     Partnered      4        3   30699     66
# 3   KP281   19    Male         12        Single      3        3   32973     85
# 4   KP281   20    Male         13     Partnered      4        2   35247     47

# %%
df.shape
# Out:
# (180, 9)

# %%
df.columns
# Out:
# Index(['Product', 'Age', 'Gender', 'Education', 'MaritalStatus', 'Usage',
#        'Fitness', 'Income', 'Miles'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
df.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# 1. The dataset has the following columns:
# - Product
# - Age
# - Gender
# - Education
# - Marital Status
# - Usage
# - Fitness
# - Income
# - Miles
#
# 2. Out of all these attributes, Product, Gender and Marital status are objects, the rest are of Int Datatype.
#
# 3. The dataset has 180 rows and 9 columns in total.
#
# 4. There are no duplicated values in the dataset
#
# 5. There are no null or missing values in the dataset

# %% [markdown]
# 2. Statistical Summary:
# - Provide an analysis of the statistical summary in few lines for both categorical and numerical features

# %%
df.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
df.describe(include = "object")
# Out:
#        Product Gender MaritalStatus
# count      180    180           180
# unique       3      2             2
# top      KP281   Male     Partnered
# freq        80    104           107

# %% [markdown]
# Statistical Summary:
#
# Numerical Features:
# 1. The minimum age is 18. The max age is 50. So the age range is (18-50).
#
# 2. The minimum education level of the users is 15.57. Because of this, it can be predicted that the users have atleast done their bachelors or are enrolled in it.
#
# 3. Usage is basically the average number of times a user plans to use the treadmill. From the data, it has been confirmed that users use treadmill atleast twice per week.
#
# 4. The average rating of fitness by the users themselves is 3.
#
# 5. The user's minimum income is 29,562 USD and the max income among the users is 1,04,581 USD.
#
# 6. The minimum miles expected by the user to travel per week are 21. and the Max miles the user expects to cover per week are 360.
#
# Categorical Features:
# 1. The data consists of 3 unique products with KP281 being the top purchase (80).
# 2. Males purchase the aerofit treadmill more than females. The distribution of males and females are 104 and 76. It means there are 28 more males.
# 3. Majority of the users are married with a count of 107.

# %% [markdown]
# 3. Non-Graphical Analysis:
# - Value Counts for all categorical features
# - Unique Attributes for all categorical features

# %%
df["Product"].value_counts()
# Out:
# Product
# KP281    80
# KP481    60
# KP781    40
# Name: count, dtype: int64

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Male      104
# Female     76
# Name: count, dtype: int64

# %%
df["MaritalStatus"].value_counts()
# Out:
# MaritalStatus
# Partnered    107
# Single        73
# Name: count, dtype: int64

# %%
female_count = df["Gender"].value_counts()["Female"]
male_count = df["Gender"].value_counts()["Male"]
male_to_female_ratio = (male_count / df.shape[0]) * 100
print(male_to_female_ratio)
# Out:
# 57.77777777777777

# %%
df.shape
# Out:
# (180, 9)

# %%
for column in df.columns:
  if df[column].dtype == object:
    print(f"Unique values for {column}: {df[column].unique()}")
# Out:
# Unique values for Product: ['KP281' 'KP481' 'KP781']
# Unique values for Gender: ['Male' 'Female']
# Unique values for MaritalStatus: ['Single' 'Partnered']

# %% [markdown]
# 1. Gender has two values: Male and Female with Male being more than female with a ratio of 57.77
# 2. 107 users are married who purchased the aerofit treadmill
# 3. the top product is KP281 (80) as discussed earlier followed by KP481 (60) and the least puchased product is KP781 with a total purchase count of 40.

# %% [markdown]
# 4. Graphical Analysis:
#
# 1.  Univariate Analysis - Numerical features:
#
#
# >  Distribution Plot
#
# > Count Plot
#
# > Box Plot
#
# 2. Univariate Analysis - Categorical features:
# > Count Plot

# %%
# D I S T R  I B U T I O N     P L O T
numerical_features = ['Age', 'Education', 'Usage', 'Fitness', 'Income', 'Miles']

fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(10, 8))

for i, feature in enumerate(numerical_features):
  row = i // 3
  col = i % 3
  sns.histplot(df[feature], kde=True, ax=axes[row, col], color = "salmon")
  axes[row, col].set_title(f'Distribution of {feature}')
  axes[row, col].set_xlabel(feature)
  axes[row, col].set_ylabel('Density')

plt.tight_layout()
plt.show()

# %% [markdown]
# 1. Users with age 25 have purchased the Treadmill in majority (58).
# 2. Users with Education level of 16 have purchased more treadmill in majority (85).
# 3. Many people use treadmill 3 times per week.
# 4. As mentioned earlier, it has been confirmed that average users considered themselves normal fitted i.e 3.
# 5. Majority of the users have income in the range of
# (50000 - 60000)
# 6. Most users tend to target 80-90 miles per week.

# %%
# C O U N T   P L O T
numerical_features = ['Age', 'Education', 'Usage', 'Fitness', 'Income', 'Miles']

fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(20, 10))

for i, feature in enumerate(numerical_features):
  row = i // 3
  col = i % 3
  sns.countplot(x = df[feature], ax=axes[row, col], color = "salmon")
  axes[row, col].set_title(f'Count Plot of {feature}')
  axes[row, col].set_xlabel(feature)
  ticks = axes[row, col].get_xticks()
  # Set the x-axis ticks and rotate the labels
  axes[row, col].set_xticks(ticks, labels=axes[row, col].get_xticklabels(), rotation=90)
  axes[row, col].set_ylabel('Density')

plt.tight_layout()
plt.show()

# %%
#  B O X    P L O T
numerical_features = ['Age', 'Education', 'Usage', 'Fitness', 'Income', 'Miles']

fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(20, 10))

for i, feature in enumerate(numerical_features):
  row = i // 3
  col = i % 3
  sns.boxplot(x = df[feature], ax=axes[row, col], color = "salmon")
  axes[row, col].set_title(f'Box Plot of {feature}')
  axes[row, col].set_xlabel(feature)
  ticks = axes[row, col].get_xticks()
  # Set the x-axis ticks and rotate the labels
  axes[row, col].set_xticks(ticks, labels=axes[row, col].get_xticklabels(), rotation=90)
  axes[row, col].set_ylabel('Density')

plt.tight_layout()
plt.show()

# %%
# Count plot for Categorical Features

categorical_features = ["Product", "Gender", "MaritalStatus"]

fig, axes = plt.subplots(nrows=1, ncols=len(categorical_features), figsize=(20, 10))

for i, feature in enumerate(categorical_features):
  sns.countplot(x = df[feature], ax=axes[i], color = "salmon")
  axes[i].set_title(f'Count of {feature}')
  axes[i].set_xlabel(feature)
  ticks = axes[i].get_xticks()
  # Set the x-axis ticks and rotate the labels
  axes[i].set_xticks(ticks, labels=axes[i].get_xticklabels(), rotation=90)
  axes[i].set_ylabel('Density')

plt.tight_layout()
plt.show()

# %% [markdown]
# 1. KP281 is the most sold Product.
# 2. Males have bought treadmill more than females.
# 3. Most buyers are married.

# %% [markdown]
# 3. Bivariate Analysis:
# - Check features eƯect on the product purchased e.g.
#
# > Product vs Gender
#
#
# > Product vs MaritalStatus
#
#
# >  Product vs Age
#
#
# > Multivariate Analysis:
#
# - Create pairplots to show relationship of features

# %%
sns.countplot(x = "Product", hue = "Gender", data = df,  palette = "magma")
plt.xlabel("Product")
plt.ylabel("Count")
plt.title("Product Purchased By Gender (Products Vs. Gender)")
plt.show()

# %%
sns.countplot(x= "Product", hue = "MaritalStatus", data = df, palette = "magma")
plt.xlabel("Product")
plt.ylabel("Count")
plt.title("Product Purchased by Marital Status (Product Vs. MaritalStatus)")
plt.show()

# %%
# Product vs Age
plt.figure(figsize=(10, 6))
sns.boxplot(x='Product', y='Age', data=df, palette='magma')
plt.xlabel('Product')
plt.ylabel('Age')
plt.title('Product Purchased by Age (Product vs. Age)')
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.pairplot(df)
plt.show()

# %% [markdown]
# # Observations from the visualizations:
#
# 1. Product Sales Distribution:
# - KP281 is the most popular product, followed by KP481 and then KP781.
# - This suggests that the entry-level and mid-level treadmills are more in demand.
#
# 2. Gender Distribution:
# - More males than females have purchased treadmills.
# - This could indicate that the target audience leans towards male customers.
#
# 3. Marital Status Distribution:
# - A majority of the buyers are partnered/married.
# - This suggests that partnered individuals are more likely to purchase a treadmill.
#
# 4. Age Distribution:
# - The age range of buyers is quite wide, with a slight concentration around the 25-35 years old range.
# - The boxplots show that there might be some variations in the age of buyers across different products.
#
# 5. Income Distribution:
# - The income distribution is somewhat skewed towards the higher end.
# - This suggests that the treadmill buyers are likely to have higher disposable incomes.
#
# 6. Product vs Gender:
# - All products seem to have a higher proportion of male buyers than female buyers.
#
# 7. Product vs Marital Status:
# - All products have a higher proportion of partnered/married buyers compared to single buyers.
#
# 8. Product vs Age:
# - There might be some differences in the age range of buyers across different product types.
# - For instance, KP781 may have a slightly older customer base than the other two products.
# 9. Pairplot:
# - It shows a combination of relationships between different features.
# - It's helpful in spotting potential correlations between features, such as income and the type of treadmill purchased.

# %% [markdown]
# ## Correlation Analysis:
# - Show the correlation matrix on heatmap and write your observation of findings in few lines.

# %%
numerical_columns = df.select_dtypes(include = ["number"])
numerical_columns
# Out:
#      Age  Education  Usage  Fitness  Income  Miles
# 0     18         14      3        4   29562    112
# 1     19         15      2        3   31836     75
# 2     19         14      4        3   30699     66
# 3     19         12      3        3   32973     85
# 4     20         13      4        2   35247     47
# ..   ...        ...    ...      ...     ...    ...
# 175   40         21      6        5   83416    200
# 176   42         18      5        4   89641    200
# 177   45         16      5        5   90886    160
# 178   47         18      4        5  104581    120
# 179   48         18      4        5   95508    180
#
# [180 rows x 6 columns]

# %%
correlation = numerical_columns.corr()
correlation
# Out:
#                 Age  Education     Usage   Fitness    Income     Miles
# Age        1.000000   0.280496  0.015064  0.061105  0.513414  0.036618
# Education  0.280496   1.000000  0.395155  0.410581  0.625827  0.307284
# Usage      0.015064   0.395155  1.000000  0.668606  0.519537  0.759130
# Fitness    0.061105   0.410581  0.668606  1.000000  0.535005  0.785702
# Income     0.513414   0.625827  0.519537  0.535005  1.000000  0.543473
# Miles      0.036618   0.307284  0.759130  0.785702  0.543473  1.000000

# %%
sns.heatmap(correlation, annot = True, cmap = "magma")
# Out:
# <Axes: >

# %% [markdown]
# # Observations from the Heatmap:
#
# 1. Strong Positive Correlation:
# - 'Miles' and 'Usage' have a strong positive correlation (0.76), which is expected as people who plan to use the treadmill more often are likely to cover more miles.
# - 'Income' and 'Miles' have a moderate positive correlation (0.54), indicating that individuals with higher incomes tend to cover more miles.
# - 'Income' and 'Usage' show a moderate positive correlation (0.52), suggesting that those with higher incomes tend to use the treadmill more frequently.
# - 'Age' and 'Fitness' have a moderate positive correlation (0.61), which implies that older individuals tend to rate their fitness higher.
# - 'Education' and 'Income' show a moderate positive correlation (0.63), which implies that users with higher education have higher income.
# 2. Moderate Correlation:
# - 'Age' and 'Income' have a moderate positive correlation (0.51), suggesting a potential trend where older individuals tend to have higher incomes.
#  - 'Education' and 'Age' have a moderate positive correlation (0.63), showing that higher education individuals may be older in age.
# 3. Weak or No Correlation:
# - 'Fitness' and 'Miles' have a very weak correlation (0.06), indicating that self-rated fitness doesn't strongly influence how many miles users plan to cover.
# - 'Fitness' and 'Usage' have a very weak correlation (0.05), indicating that self-rated fitness doesn't strongly influence how many times users plan to use the treadmill per week.
#
#
# Based on the correlation matrix, it's evident that 'Usage' and 'Miles' are strongly positively correlated, and 'Income' is moderately correlated with both of them.
# This indicates that users who plan to use the treadmill more and cover more miles tend to have higher incomes.
# Additionally, 'Age' and 'Fitness' are moderately positively correlated, suggesting that older individuals may rate their fitness higher.

# %% [markdown]
# ## Outlier Detection:
# - Check for the outliers by using the IQR method.

# %%
def iqr_outliers(df):
  Q1 = np.percentile(df, 25)
  Q3 = np.percentile(df, 75)
  iqr = Q3 - Q1
  lower_bound = Q1 - 1.5 *iqr
  upper_bound = Q3 + 1.5*iqr
  outliers = [x for x in df if x < lower_bound or x > upper_bound]
  return outliers

# %%
print(numerical_features)
# Out:
# ['Age', 'Education', 'Usage', 'Fitness', 'Income', 'Miles']

# %%
for features in numerical_features:
  outliers = iqr_outliers(df[features])
  print(f"Outliers in {features}: {outliers}")
# Out:
# Outliers in Age: [47, 50, 48, 47, 48]
# Outliers in Education: [20, 21, 21, 21]
# Outliers in Usage: [6, 6, 6, 7, 6, 7, 6, 6, 6]
# Outliers in Fitness: [1, 1]
# Outliers in Income: [83416, 88396, 90886, 92131, 88396, 85906, 90886, 103336, 99601, 89641, 95866, 92131, 92131, 104581, 83416, 89641, 90886, 104581, 95508]
# Outliers in Miles: [188, 212, 200, 200, 200, 240, 300, 280, 260, 200, 360, 200, 200]

# %% [markdown]
# ## Conditional Probabilities:

# %% [markdown]
# What percent of customers have purchased KP281, KP481, or KP781?

# %%
percentage_cust = round(df["Product"].value_counts(normalize = True) * 100, 2)
# percentage_cust
customer_product_purchased = pd.DataFrame({
    "Product" : percentage_cust.index,
    "Percentage (%)" : percentage_cust.values
})
customer_product_purchased
# Out:
#   Product  Percentage (%)
# 0   KP281           44.44
# 1   KP481           33.33
# 2   KP781           22.22

# %% [markdown]
# Create frequency tables and calculate the percentage as follows
# - Product – Gender
# 1.  Percentage of a Male customer purchasing a treadmill
# 2.  Percentage of a Female customer purchasing KP781 treadmill
# 3. Probability of a customer being a Female given that Product is
# KP281

# %%
# percentage of male customers purchasing a treadmill
male_count = round((df["Gender"].value_counts(normalize = True)["Male"]) * 100, 2)
# male_count
male_customers_purchased = pd.DataFrame({
    "Gender" : ["Males"],
    "percentage (%)" : male_count
})
male_customers_purchased
# Out:
#   Gender  percentage (%)
# 0  Males           57.78

# %%
# count of customers who bought KP781 by gender
df[df["Product"] == "KP781"]["Gender"].value_counts()
# Out:
# Gender
# Male      33
# Female     7
# Name: count, dtype: int64

# %%
# extracting just the female count
df[(df["Product"] == "KP781")]["Gender"].value_counts()["Female"]
# Out:
# 7

# %%
# Percentage of female customers who bought KP781 treadmill.
female_KP781 = round((df[(df["Product"] == "KP781")]["Gender"].value_counts(normalize = True)["Female"]) * 100, 2)
female_KP781_percentage = pd.DataFrame({
    "Gender" : ["Females"],
    "Percentage (%) of females who bought KP781" : female_KP781
})

female_KP781_percentage
# Out:
#     Gender  Percentage (%) of females who bought KP781
# 0  Females                                        17.5

# %%
# count of females who bought KP281
female_count_KP281 = df[df["Product"] == "KP281"]["Gender"].value_counts()["Female"]
female_count_KP281
# Out:
# 40

# %%
# total count of KP281 purchased
KP281_count = df["Product"].value_counts()["KP281"]
KP281_count
# Out:
# 80

# %%
# finding probablity of customers being female given that product is KP281
probability_female_KP281 = female_count_KP281 / KP281_count
probability_female_KP281
# Out:
# 0.5

# %%
# fact table for the probablity of customers being female given that product is KP281
probability_fact = pd.DataFrame({
    "Gender": ["Female"],
    "Female_Kp281_count" : female_count_KP281,
    "KP281_count" : KP281_count,
    "Probability of customer being female and product is KP281" : probability_female_KP281
})

probability_fact
# Out:
#    Gender  Female_Kp281_count  KP281_count  \
# 0  Female                  40           80
#
#    Probability of customer being female and product is KP281
# 0                                                0.5

# %% [markdown]
# - Product – Age
# 1.  Percentage of customers with Age between 20s and 30s among all
# customers

# %%
# count of customers with age between 20s and 30s among all customers
((df["Age"] >=20) & (df["Age"]>=30)).value_counts()[True]
# Out:
# 67

# %%
# percentage of customers with age between 20s and 30s among all customers
age_percentage = round((((df["Age"] >=20) & (df["Age"]>=30)).value_counts(normalize = True)[True]) * 100, 2)
age_percentage
# Out:
# 37.22

# %%
# fact table for percentage of customers with age between 20s and 30s among all customers
age_percentage_fact = pd.DataFrame({
    "Age" : ["20s to 30s"],
    "Percentage (%)" : age_percentage
})

age_percentage_fact
# Out:
#           Age  Percentage (%)
# 0  20s to 30s           37.22

# %% [markdown]
# - Product – Income
# 1. Percentage of a low-income customer purchasing a treadmill
# 2. Percentage of a high-income customer purchasing KP781
# treadmill
# 3. Percentage of customer with high-income salary buying treadmill
# given that Product is KP781

# %%
# low_income threshold
low_income_threshold = 50000

# %%
# low income customers count
low_income_customers = df[df["Income"] <= low_income_threshold].shape[0]
low_income_customers
# Out:
# 83

# %%
# total_customers
total_customers = df.shape[0]
total_customers
# Out:
# 180

# %%
# percentage of low income customers purchasing a treadmill

percentage_low_income = round((low_income_customers / total_customers) * 100, 2)

# percentage_low_income

percentage_low_income_fact = pd.DataFrame({
    "Low Income Customers" : [low_income_customers],
    "total_customers" : [total_customers],
    "Percentage of low income customers" : [percentage_low_income]
})
percentage_low_income_fact
# Out:
#    Low Income Customers  total_customers  Percentage of low income customers
# 0                    83              180                               46.11

# %%
# High-income threshold
high_income_threshold = 80000

# Customers with high income who purchased KP781
high_income_kp781_customers = df[(df['Income'] >= high_income_threshold) & (df['Product'] == 'KP781')].shape[0]

# Total number of customers who purchased KP781
total_kp781_customers = df[df['Product'] == 'KP781'].shape[0]

# Percentage of high-income customers purchasing KP781
percentage_high_income_kp781 = (high_income_kp781_customers / total_kp781_customers) * 100 if total_kp781_customers > 0 else 0

percentage_high_income_kp78_fact = pd.DataFrame({
    "High Income Customers" : [high_income_kp781_customers],
    "Total KP781 Customers" : [total_kp781_customers],
    "Percentage of high income customers purchasing KP781" : [percentage_high_income_kp781]
})

percentage_high_income_kp78_fact
# Out:
#    High Income Customers  Total KP781 Customers  \
# 0                     19                     40
#
#    Percentage of high income customers purchasing KP781
# 0                                               47.5

# %%
# Customers with high income who purchased KP781
high_income_kp781_customers = df[(df['Income'] >= high_income_threshold) & (df['Product'] == 'KP781')].shape[0]

# Total number of customers who purchased KP781
total_kp781_customers = df[df['Product'] == 'KP781'].shape[0]

# Percentage of high-income customers purchasing KP781 given that the product is KP781
percentage_high_income_kp781_given_kp781 = (high_income_kp781_customers / total_kp781_customers) * 100 if total_kp781_customers > 0 else 0

percentage_high_income_kp781_given_kp781_fact = pd.DataFrame({
    "High Income Customers who bought KP781" : [high_income_kp781_customers],
    "Total KP781 Customers" : [total_kp781_customers],
    "Percentage of high income customers purchasing KP781 given KP781" : [percentage_high_income_kp781_given_kp781]
})

percentage_high_income_kp781_given_kp781_fact
# Out:
#    High Income Customers who bought KP781  Total KP781 Customers  \
# 0                                      19                     40
#
#    Percentage of high income customers purchasing KP781 given KP781
# 0                                               47.5

# %% [markdown]
# - Product – Fitness
# 1. Percentage of customers that have fitness level 5
# 2. Percentage of a customer with Fitness Level 5 purchasing KP781
# treadmill
# 3. Percentage of customer with fitness level 5 buying KP781
# treadmill

# %%
percentage_fitness_5 = round((df["Fitness"].value_counts(normalize = True)[5]) * 100, 2)
# print(f"The Percentage of customers that have fitness level 5 is : {percentage_fitness_5}%")

percentage_fitness_5_fact = pd.DataFrame({
    "Fitness Level" : [5],
    "Percentage (%)" : [percentage_fitness_5]
})

percentage_fitness_5_fact
# Out:
#    Fitness Level  Percentage (%)
# 0              5           17.22

# %%
percentage_fitness_5_product_kp781 = round((df[(df["Fitness"] ==5)]["Product"].value_counts(normalize = True)["KP781"]) * 100, 2)

percentage_fitness_5_product_kp781_fact = pd.DataFrame({
    "Fitness Level" : [5],
    "Percentage (%)" : [percentage_fitness_5_product_kp781]
})

percentage_fitness_5_product_kp781_fact
# Out:
#    Fitness Level  Percentage (%)
# 0              5           93.55

# %%
fitness_5_kp781_customers = df[(df['Fitness'] == 5) & (df['Product'] == 'KP781')]
num_fitness_5_kp781_customers = len(fitness_5_kp781_customers)
num_kp781_customers = len(df[df['Product'] == 'KP781'])

percentage_fitness_5_kp781 = round((num_fitness_5_kp781_customers / num_kp781_customers) * 100, 2)
percentage_fitness_5_kp781_buying = pd.DataFrame({
    "Fitness Level" : [5],
    "Percentage (%)" : [percentage_fitness_5_kp781]
})

percentage_fitness_5_kp781_buying
# Out:
#    Fitness Level  Percentage (%)
# 0              5            72.5

# %% [markdown]
# - Product - Marital Status
# 1. Percentage of a customers who are partnered using treadmills

# %%
partnered_customers = df[df['MaritalStatus'] == 'Partnered'].shape[0]
partnered_customers
# Out:
# 107

# %%
total_customers
# Out:
# 180

# %%
percentage_partnered = round((partnered_customers / total_customers) * 100, 2)
percentage_partnered
# Out:
# 59.44

# %%
partnered_percentage_fact = pd.DataFrame({
    'Marital Status': ['Partnered'],
    'Percentage (%)': [percentage_partnered]
})

partnered_percentage_fact
# Out:
#   Marital Status  Percentage (%)
# 0      Partnered           59.44

# %% [markdown]
# # Actionable Insights & Recommendations:
# Based on the analysis conducted, here are some actionable insights and recommendations:
#
# **1. Target Audience:**
# - The target audience for Aerofit treadmills primarily consists of males, particularly those who are partnered/married.
# - **Recommendation:** Focus marketing efforts on these segments, highlighting the benefits and features that cater to their specific needs.
# - **Recommendation:** Consider tailoring marketing campaigns and promotional offers to attract and retain male customers.
#
# **2. Product Portfolio:**
# - KP281 and KP481 are the most popular products, indicating a preference for mid-range and entry-level models.
# - **Recommendation:** Continue investing in developing and promoting these products to capitalize on their market demand.
# - **Recommendation:** Consider introducing new models that fall within these price ranges and cater to specific customer needs, such as features related to fitness tracking, entertainment options, and customization.
#
# **3. Pricing Strategy:**
# - The moderate correlation between income and usage/miles suggests that price sensitivity may exist.
# - **Recommendation:** Analyze the relationship between price points and sales volumes for each product to optimize pricing strategies.
# - **Recommendation:** Explore options like tiered pricing or bundled offers to attract customers across different income levels while maximizing revenue.
#
# **4. Marketing Strategies:**
# - **Recommendation:** Highlight the health and fitness benefits of owning a treadmill, particularly targeting those with higher incomes or greater interest in exercise.
# - **Recommendation:** Use targeted advertising and promotions to reach potential customers based on demographics (age, gender, marital status) and interests (fitness, sports, health).
# - **Recommendation:** Develop content marketing strategies that focus on providing valuable information about the benefits of regular exercise, fitness tips, and how treadmills can help achieve specific goals.
#
# **5. Customer Retention:**
# - **Recommendation:** Encourage customer loyalty by building a strong relationship with users, providing excellent after-sales support, and offering exclusive benefits.
# - **Recommendation:** Consider launching programs like fitness challenges, user communities, or educational resources to increase engagement and retain existing customers.
# - **Recommendation:** Collect customer feedback through surveys or online reviews to understand their experiences and address any pain points.
#
# **6. Product Improvements:**
# - **Recommendation:** Research potential improvements to product features, taking into consideration factors like age and fitness levels.
# - **Recommendation:** Analyze data from customers with a fitness level of 5 and those who purchase KP781 to assess the need for additional advanced features.
# - **Recommendation:** Introduce features that cater to users' preferences, such as improved console interfaces, personalized workout programs, and advanced tracking capabilities.
#
# **7. Geographic Targeting:**
# - **Recommendation:** Consider conducting market research to understand the specific geographical areas where there is a high demand for treadmills.
# - **Recommendation:** Tailor marketing campaigns and product availability based on regional preferences and needs.
# - **Recommendation:** Consider partnering with fitness centers or gyms in specific locations to increase product awareness and sales.
#
# **8. Data-Driven Decisions:**
# - **Recommendation:** Continue utilizing data analysis to monitor sales trends, customer behaviors, and marketing campaign effectiveness.
# - **Recommendation:** Use insights derived from the analysis to inform decision-making, optimize pricing, and refine marketing strategies.
# - **Recommendation:** Invest in building a robust data analytics infrastructure to enable efficient data collection, analysis, and reporting.
